# %%
# Importing Libraries

import numpy as np
import webbrowser
import cv2
import os, sys
import time
import operator
import tensorflow as tf
from string import ascii_uppercase

import tkinter as tk
from PIL import Image, ImageTk

import tkinter as tk
from ttkthemes import ThemedTk
import enchant
from ttkthemes import ThemedTk, ThemedStyle
from keras.models import model_from_json


#Application :

class Application:

    def __init__(self):

        
        self.vs = cv2.VideoCapture(0)
        self.current_image = None
        self.current_image2 = None
        self.json_file = open("model_new.json", "r")
        self.model_json = self.json_file.read()
        self.json_file.close()
        self.loaded_model = model_from_json(self.model_json)
        self.loaded_model.load_weights("model_new.h5")

        self.json_file_dru = open("model_new_dru.json" , "r")
        self.model_json_dru = self.json_file_dru.read()
        self.json_file_dru.close()
        self.loaded_model_dru = model_from_json(self.model_json_dru)
        self.loaded_model_dru.load_weights("model_new_dru.h5")
        
        
        self.json_file_tkdi = open("model_new_tkdi.json" , "r")
        self.model_json_tkdi = self.json_file_tkdi.read()
        self.json_file_tkdi.close()
        self.loaded_model_tkdi = model_from_json(self.model_json_tkdi)
        self.loaded_model_tkdi.load_weights("model_new_tkdi.h5")
        
        
        self.json_file_smn = open("model_new_smn.json" , "r")
        self.model_json_smn = self.json_file_smn.read()
        self.json_file_smn.close()
        self.loaded_model_smn = model_from_json(self.model_json_smn)
        self.loaded_model_smn.load_weights("model_new_smn.h5")
        
        self.json_file_fbi = open("model_new_fbi.json" , "r")
        self.model_json_fbi = self.json_file_fbi.read()
        self.json_file_fbi.close()
        self.loaded_model_fbi = model_from_json(self.model_json_fbi)
        self.loaded_model_fbi.load_weights("model_new_fbi.h5")

        self.json_file_tsd = open("model_new_tsd.json" , "r")
        self.model_json_tsd = self.json_file_tsd.read()
        self.json_file_tsd.close()
        self.loaded_model_tsd = model_from_json(self.model_json_tsd)
        self.loaded_model_tsd.load_weights("model_new_tsd.h5")

        self.json_file_sdx = open("model_new_sdx.json" , "r")
        self.model_json_sdx = self.json_file_sdx.read()
        self.json_file_sdx.close()
        self.loaded_model_sdx = model_from_json(self.model_json_sdx)
        self.loaded_model_sdx.load_weights("model_new_sdx.h5")

        # self.json_file_eam = open("model_new_eam.json" , "r")
        # self.model_json_eam = self.json_file_eam.read()
        # self.json_file_eam.close()
        # self.loaded_model_eam = model_from_json(self.model_json_eam)
        # self.loaded_model_eam.load_weights("model_new_eam.h5")

        # self.json_file_sdx = open("model_new_ghp.json" , "r")
        # self.model_json_ = self.json_file_ghp.read()
        # self.json_file_ghp.close()
        # self.loaded_model_ghp = model_from_json(self.model_json_ghp)
        # self.loaded_model_ghp.load_weights("model_new_ghp.h5")

        self.ct = {}
        self.ct['blank'] = 0
        self.blank_flag = 0

        for i in ascii_uppercase:
            self.ct[i] = 0
        
        print("Loaded model from disk")

        self.root = ThemedTk(theme="equilux")  # Choose the theme you prefer
        self.root.get_themes()  # Get available themes

        self.root.set_theme("equilux")  # Set the theme (you can change this to a different theme)

        self.root.title("ASL CONVERTER")
        self.root.protocol('WM_DELETE_WINDOW', self.destructor)
        self.root.geometry("900x900")
        self.root.configure(bg="#72b1b7")
        # Main Title (Header)
        self.T = tk.Label(self.root, text="Sign Language To Text Conversion", font=("Arial", 24, "bold"), background="#A4C7E7", foreground="white")
        self.T.pack(fill=tk.X)

        # Image Panels (Body)
        self.panel = tk.Label(self.root, background="#5a99d1")
        self.panel.place(x=100, y=50, width=580, height=580)
        
        self.panel2 = tk.Label(self.root, background="#5a99d1")
        self.panel2.place(x=400, y=65, width=275, height=275)

        # Labels for Character, Word, Sentence (Body)
        label_font = ("Arial", 16, "bold")

        # Labels for Character, Word, Sentence (Body)
# Labels for Character, Word, Sentence (Body)
        label_font = ("Arial", 16, "bold")
        
        self.T1 = tk.Label(self.root, text="Letter :", font=label_font, background="#72b1b7", foreground="black")
        self.T1.place(x=700, y=100)
        
        self.T2 = tk.Label(self.root, text="Word :", font=label_font, background="#72b1b7", foreground="black")
        self.T2.place(x=700, y=150)
        
        self.T3 = tk.Label(self.root, text="Sentence:", font=label_font, background="#72b1b7", foreground="black")
        self.T3.place(x=700, y=200)
        
        # Display for Current Symbol, Word, and Sentence (Body)
        display_font = ("Arial", 16)
        
        self.panel3 = tk.Label(self.root, background="#72b1b7", font=display_font)
        self.panel3.place(x=800, y=100)
        
        self.panel4 = tk.Label(self.root, background="#72b1b7", font=display_font)
        self.panel4.place(x=800, y=150)
        
        self.panel5 = tk.Label(self.root, background="#72b1b7", font=display_font)
        self.panel5.place(x=800, y=200)



        self.select_letter_button = tk.Button(
        self.root, text="Select Letter", font=("Arial", 14),
        command=self.select_letter)
        self.select_letter_button.place(x=400, y=700)  # Adjusted y-coordinate

        self.website_url = "https://raashaahmad.github.io/ASL-Learning-Platform.github.io/"


        self.button = tk.Button(self.root, text="ASL Learning Platform Home", command=self.open_website, font=("Arial", 10))
        self.button.place(x=700, y=50, width=200, height=30)
    
    # Delete Button
        self.delete_button = tk.Button(
        self.root, text="Delete", font=("Arial", 14),
        command=self.delete_letter)
        self.delete_button.place(x=550, y=700)


        

        


        self.str = ""
        self.word = " "
        self.current_symbol = "Empty"
        self.photo = "Empty"
        self.video_loop()


    def video_loop(self):
        ok, frame = self.vs.read()

        if ok:
            cv2image = cv2.flip(frame, 1)

            x1 = int(0.5 * frame.shape[1])
            y1 = 10
            x2 = frame.shape[1] - 10
            y2 = int(0.5 * frame.shape[1])

            cv2.rectangle(frame, (x1 - 1, y1 - 1), (x2 + 1, y2 + 1), (255, 0, 0) ,1)
            cv2image = cv2.cvtColor(cv2image, cv2.COLOR_BGR2RGBA)

            self.current_image = Image.fromarray(cv2image)
            imgtk = ImageTk.PhotoImage(image = self.current_image)

            self.panel.imgtk = imgtk
            self.panel.config(image = imgtk)

            cv2image = cv2image[y1 : y2, x1 : x2]

            gray = cv2.cvtColor(cv2image, cv2.COLOR_BGR2GRAY)

            blur = cv2.GaussianBlur(gray, (5, 5), 2)

            th3 = cv2.adaptiveThreshold(blur, 255 ,cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV, 11, 2)

            ret, res = cv2.threshold(th3, 70, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
            
            res=cv2.cvtColor(res,cv2.COLOR_GRAY2RGB)
            
            self.predict(res)

            self.current_image2 = Image.fromarray(res)

            imgtk = ImageTk.PhotoImage(image = self.current_image2)

            self.panel2.imgtk = imgtk
            self.panel2.config(image = imgtk)

            self.panel3.config(text = self.current_symbol, font = ("Courier", 30))

            self.panel4.config(text = self.word, font = ("Courier", 30))

            self.panel5.config(text = self.str,font = ("Courier", 30))

           

              


        self.root.after(5, self.video_loop)

    def predict(self, test_image):

        test_image_resized = cv2.resize(test_image, (128, 128))
        
        test_image_normalized = tf.keras.applications.resnet50.preprocess_input(test_image_resized)
        
        test_image_shaped=np.expand_dims(test_image_normalized,axis=0)

        result = self.loaded_model.predict(test_image_shaped)


        result_dru = self.loaded_model_dru.predict(test_image_shaped)

        result_tkdi = self.loaded_model_tkdi.predict(test_image_shaped)

        result_smn = self.loaded_model_smn.predict(test_image_shaped)
        
        result_fbi = self.loaded_model_fbi.predict(test_image_shaped)

        result_sdx = self.loaded_model_sdx.predict(test_image_shaped)

        result_tsd = self.loaded_model_tsd.predict(test_image_shaped)

        # result_eam = self.loaded_model_eam.predict(test_image_shaped)

        # result_ghp = self.loaded_model_ghp.predict(test_image_shaped)

        prediction = {}

        prediction['blank'] = result[0][0]

        inde = 1

        for i in ascii_uppercase:

            prediction[i] = result[0][inde]

            inde += 1

        #LAYER 1

        prediction = sorted(prediction.items(), key = operator.itemgetter(1), reverse = True)

        self.current_symbol = prediction[0][0]


#         #LAYER 2

        if(self.current_symbol == 'D' or self.current_symbol == 'R' or self.current_symbol == 'U'):

        	prediction = {}

        	prediction['D'] = result_dru[0][0]
        	prediction['R'] = result_dru[0][1]
        	prediction['U'] = result_dru[0][2]

        	prediction = sorted(prediction.items(), key = operator.itemgetter(1), reverse = True)

        	self.current_symbol = prediction[0][0]
        
        
        
        if(self.current_symbol == 'F' or self.current_symbol == 'B' or self.current_symbol == 'I'):

        	prediction = {}

        	prediction['F'] = result_fbi[0][0]
        	prediction['B'] = result_fbi[0][1]
        	prediction['I'] = result_fbi[0][2]

        	prediction = sorted(prediction.items(), key = operator.itemgetter(1), reverse = True)

        	self.current_symbol = prediction[0][0]

        # if(self.current_symbol == 'E' or self.current_symbol == 'A' or self.current_symbol == 'M'):

        # 	prediction = {}

        # 	prediction['E'] = result_eam[0][0]
        # 	prediction['A'] = result_eam[0][1]
        # 	prediction['M'] = result_eam[0][2]

        # 	prediction = sorted(prediction.items(), key = operator.itemgetter(1), reverse = True)

        # 	self.current_symbol = prediction[0][0]

        # if(self.current_symbol == 'G' or self.current_symbol == 'H' or self.current_symbol == 'P'):

        # 	prediction = {}

        # 	prediction['G'] = result_ghp[0][0]
        # 	prediction['H'] = result_ghp[0][1]
        # 	prediction['P'] = result_ghp[0][2]

        # 	prediction = sorted(prediction.items(), key = operator.itemgetter(1), reverse = True)

        # 	self.current_symbol = prediction[0][0]

        if(self.current_symbol == 'S' or self.current_symbol == 'D' or self.current_symbol == 'X'):
            

        	prediction = {}

        	prediction['S'] = result_sdx[0][0]
        	prediction['D'] = result_sdx[0][1]
        	prediction['X'] = result_sdx[0][2]

        	prediction = sorted(prediction.items(), key = operator.itemgetter(1), reverse = True)

        	self.current_symbol = prediction[0][0]

        if(self.current_symbol == 'T' or self.current_symbol == 'S' or self.current_symbol == 'D'):

        	prediction = {}

        	prediction['T'] = result_tsd[0][0]
        	prediction['S'] = result_tsd[0][1]
        	prediction['D'] = result_tsd[0][2]

        	prediction = sorted(prediction.items(), key = operator.itemgetter(1), reverse = True)

        	self.current_symbol = prediction[0][0]
        
        
        
        

        if(self.current_symbol == 'D' or self.current_symbol == 'I' or self.current_symbol == 'K' or self.current_symbol == 'T'):

        	prediction = {}

        	prediction['D'] = result_tkdi[0][0]
        	prediction['I'] = result_tkdi[0][1]
        	prediction['K'] = result_tkdi[0][2]
        	prediction['T'] = result_tkdi[0][3]
            

        	prediction = sorted(prediction.items(), key = operator.itemgetter(1), reverse = True)

        	self.current_symbol = prediction[0][0]

        if(self.current_symbol == 'M' or self.current_symbol == 'N' or self.current_symbol == 'S'):

        	prediction1 = {}

        	prediction1['M'] = result_smn[0][0]
        	prediction1['N'] = result_smn[0][1]
        	prediction1['S'] = result_smn[0][2]

        	prediction1 = sorted(prediction1.items(), key = operator.itemgetter(1), reverse = True)

        	if(prediction1[0][0] == 'S'):

        		self.current_symbol = prediction1[0][0]

        	else:

        		self.current_symbol = prediction[0][0]
        
        if(self.current_symbol == 'blank'):

            for i in ascii_uppercase:
                self.ct[i] = 0

        self.ct[self.current_symbol] += 1
#transition code

        
        if(self.ct[self.current_symbol] > 6):

            for i in ascii_uppercase:
                if i == self.current_symbol:
                    continue

                tmp = self.ct[self.current_symbol] - self.ct[i]

                if tmp < 0:
                    tmp *= -1

                if tmp <= 4:
                    self.ct['blank'] = 0

                    for i in ascii_uppercase:
                        self.ct[i] = 0
                    return

            self.ct['blank'] = 0

            for i in ascii_uppercase:
                self.ct[i] = 0

            if self.current_symbol == 'blank':

                if self.blank_flag == 0:
                    self.blank_flag = 1

                    if len(self.str) > 0:
                        self.str += " "

                    self.str += self.word

                    self.word = ""

            else:

                if(len(self.str) > 1):
                    self.str = ""

                self.blank_flag = 0

                self.word += self.current_symbol

    def select_letter(self):
        if self.current_symbol != "Empty":
            self.word += self.current_symbol
            self.panel4.config(text=self.word, font=("Courier", 30))

    def delete_letter(self):
        if len(self.word) > 0:
            self.word = self.word[:-1]
            self.panel4.config(text=self.word, font=("Courier", 30))

    def open_website(self):
        webbrowser.open(self.website_url)
            
    def destructor(self):

        print("Closing Application...")

        self.root.destroy()
        self.vs.release()
        cv2.destroyAllWindows()
    
print("Starting Application...")

(Application()).root.mainloop()
# Out:
# Starting Application...
# Loaded model from disk
# 1/1 [==============================] - 1s 879ms/step
# 1/1 [==============================] - 1s 917ms/step
# 1/1 [==============================] - 1s 873ms/step
# 1/1 [==============================] - 1s 959ms/step
# 1/1 [==============================] - 1s 859ms/step
# 1/1 [==============================] - 1s 898ms/step
# 1/1 [==============================] - 1s 813ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 383ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 265ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 244ms/step
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 263ms/step
# 1/1 [==============================] - 0s 431ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 270ms/step
# 1/1 [==============================] - 0s 309ms/step
# 1/1 [==============================] - 1s 521ms/step
# 1/1 [==============================] - 1s 543ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 235ms/step
# 1/1 [==============================] - 0s 373ms/step
# 1/1 [==============================] - 0s 439ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 452ms/step
# 1/1 [==============================] - 0s 300ms/step
# 1/1 [==============================] - 0s 310ms/step
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 223ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 1s 530ms/step
# 1/1 [==============================] - 0s 480ms/step
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 386ms/step
# 1/1 [==============================] - 0s 274ms/step
# 1/1 [==============================] - 1s 561ms/step
# 1/1 [==============================] - 0s 495ms/step
# 1/1 [==============================] - 0s 432ms/step
# 1/1 [==============================] - 0s 287ms/step
# 1/1 [==============================] - 1s 533ms/step
# 1/1 [==============================] - 0s 230ms/step
# 1/1 [==============================] - 0s 467ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 286ms/step
# 1/1 [==============================] - 0s 487ms/step
# 1/1 [==============================] - 1s 507ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 240ms/step
# 1/1 [==============================] - 1s 557ms/step
# 1/1 [==============================] - 1s 563ms/step
# 1/1 [==============================] - 1s 511ms/step
# 1/1 [==============================] - 0s 231ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 240ms/step
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 254ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 256ms/step
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 401ms/step
# 1/1 [==============================] - 0s 247ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 257ms/step
# 1/1 [==============================] - 0s 240ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 1s 520ms/step
# 1/1 [==============================] - 1s 731ms/step
# 1/1 [==============================] - 1s 725ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 494ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 481ms/step
# 1/1 [==============================] - 0s 254ms/step
# 1/1 [==============================] - 0s 403ms/step
# 1/1 [==============================] - 1s 609ms/step
# 1/1 [==============================] - 0s 304ms/step
# 1/1 [==============================] - 0s 271ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 498ms/step
# 1/1 [==============================] - 0s 304ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 1s 529ms/step
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 419ms/step
# 1/1 [==============================] - 0s 417ms/step
# 1/1 [==============================] - 0s 384ms/step
# 1/1 [==============================] - 0s 497ms/step
# 1/1 [==============================] - 0s 432ms/step
# 1/1 [==============================] - 1s 543ms/step
# 1/1 [==============================] - 0s 223ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 440ms/step
# 1/1 [==============================] - 1s 524ms/step
# 1/1 [==============================] - 1s 529ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 464ms/step
# 1/1 [==============================] - 0s 445ms/step
# 1/1 [==============================] - 1s 502ms/step
# 1/1 [==============================] - 0s 223ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 1s 562ms/step
# 1/1 [==============================] - 1s 528ms/step
# 1/1 [==============================] - 0s 238ms/step
# 1/1 [==============================] - 0s 226ms/step
# 1/1 [==============================] - 0s 288ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 256ms/step
# 1/1 [==============================] - 0s 499ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 350ms/step
# 1/1 [==============================] - 1s 539ms/step
# 1/1 [==============================] - 1s 544ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 272ms/step
# 1/1 [==============================] - 0s 494ms/step
# 1/1 [==============================] - 1s 565ms/step
# 1/1 [==============================] - 0s 418ms/step
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 530ms/step
# 1/1 [==============================] - 0s 431ms/step
# 1/1 [==============================] - 0s 238ms/step
# 1/1 [==============================] - 1s 565ms/step
# 1/1 [==============================] - 1s 510ms/step
# 1/1 [==============================] - 0s 352ms/step
# 1/1 [==============================] - 0s 366ms/step
# 1/1 [==============================] - 1s 513ms/step
# 1/1 [==============================] - 1s 546ms/step
# 1/1 [==============================] - 0s 227ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 367ms/step
# 1/1 [==============================] - 0s 481ms/step
# 1/1 [==============================] - 1s 562ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 417ms/step
# 1/1 [==============================] - 0s 224ms/step
# Closing Application...
